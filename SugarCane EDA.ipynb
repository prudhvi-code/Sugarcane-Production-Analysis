# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace('.','')
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','.')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
df.rename(columns={'Production(Tons);':'Production(Tons)'},inplace=True)	
df.rename(columns={'Production per Person (Kg)':'Production_per_Person(Kg)'},inplace=True)
df.rename(columns={'Acreage (Hectare)':"Acreage(Hectare)"},inplace=True)
df.rename(columns={'Yield (Kg / Hectare)':"Yield(Kg/Hectare"},inplace=True)
df.rename(columns={'Yield(Kg/Hectare':"Yield(Kg/Hectare)"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df['Acreage(Hectare)'].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
df=df.dropna().reset_index()

# %%
df.head(100)
# Out:
#     index  Unnamed: 0    Country      Continent Production(Tons)  \
# 0       0           0     Brazil  South America        768678382
# 1       1           1      India           Asia        348448000
# 2       2           2      China           Asia        123059739
# 3       3           3   Thailand           Asia         87468496
# 4       4           4   Pakistan           Asia         65450704
# ..    ...         ...        ...            ...              ...
# 95     95          95       Oman           Asia             1186
# 96     96          96      Yemen           Asia              500
# 97     97          97      Spain         Europe              394
# 98     98          98    Lebanon           Asia               97
# 99    100         100  Singapore           Asia               50
#
#    Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                   3668.531         10226205           75167.5
# ...

# %%
df.drop(['index','Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    102 non-null    object
#  1   Continent                  102 non-null    object
#  2   Production(Tons)           102 non-null    object
#  3   Production_per_Person(Kg)  102 non-null    object
#  4   Acreage(Hectare)           102 non-null    object
#  5   Yield(Kg/Hectare)          102 non-null    object
# dtypes: object(6)
# memory usage: 4.9+ KB

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df['Production(Tons)']=df['Production(Tons)'].astype('float')
df['Production_per_Person(Kg)']=df['Production_per_Person(Kg)'].astype('float')
df['Acreage(Hectare)']=df['Acreage(Hectare)'].astype('float')
df['Yield(Kg/Hectare)']=df['Yield(Kg/Hectare)'].astype('float')

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.distplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.distplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.distplot(df['Yield(Kg/Hectare)'])
# Out:
# C:\Users\prudh\AppData\Local\Temp\ipykernel_21276\2467860319.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production(Tons)'])
# C:\Users\prudh\AppData\Local\Temp\ipykernel_21276\2467860319.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person(Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg/Hectare)'])
plt.tight_layout()

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
dfnew=df[['Country','Production(Tons)']].set_index('Country')

# %%
dfnew
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
dfnew['Production(Tons)_percent']=dfnew['Production(Tons)']*100/(dfnew['Production(Tons)'].sum())

# %%
dfnew
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
dfnew['Production(Tons)_percent'].plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
dfnew['Production(Tons)'].head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
colors = sns.color_palette("cool", 10) 
pt=sns.barplot(data=df.head(10),x='Country',y='Production(Tons)',palette=colors) 

plt.show()
# Out:
# C:\Users\prudh\AppData\Local\Temp\ipykernel_21276\1785899972.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   pt=sns.barplot(data=df.head(10),x='Country',y='Production(Tons)',palette=colors)

# %%
colors = sns.color_palette("icefire", 10) 
plt.figure(figsize=(10, 6))
dfacr=df.sort_values('Acreage(Hectare)',ascending=False)
pt=sns.barplot(data=dfacr.head(10),x='Country',y='Acreage(Hectare)',hue='Country',palette=colors) 

plt.show()

# %%
colors = sns.color_palette("Set3", 10) 
plt.figure(figsize=(10, 6))
dfyield=df.sort_values('Yield(Kg/Hectare)',ascending=False)
pt=sns.barplot(data=dfyield.head(10),x='Country',y='Yield(Kg/Hectare)',hue='Country',palette=colors) 
plt.xticks(rotation=45)

plt.show()

# %%
colors = sns.color_palette("Set1", 10) 
plt.figure(figsize=(10, 6))
dfpro=df.sort_values('Production_per_Person(Kg)',ascending=False)
pt=sns.barplot(data=dfpro.head(10),x='Country',y='Production_per_Person(Kg)',hue='Country',palette=colors) 
plt.xticks(rotation=45)

plt.show()

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
dfcor=df.drop(columns=['Country','Continent'],axis=1)

# %%
dfcor.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_Person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
sns.heatmap(dfcor.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x='Acreage(Hectare)',y='Production(Tons)')
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
sns.scatterplot(data=df,x='Yield(Kg/Hectare)',y='Production(Tons)')
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %%
dfconti=df.groupby('Continent').sum().drop(columns=['Country'],axis=1)

# %%
dfconti
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# Africa                 2142107.5
# Asia                   1171871.4
# Europe                  131870.9
# North America          1082602.4
# Oceania                 162419.1
# South America           677192.7

# %%
dfconti.sort_values('Production(Tons)',ascending=False)
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# South America       865588126.0                3505531.738        11369236.0
# Asia                721930425.0                1857769.303        10608319.0
# North America       173995947.0                3796081.508         1581983.0
# Africa               89681472.0                2332636.293         1439089.0
# Oceania              36177574.0                  28593.605          490909.0
# Europe                   5823.0                    536.000              71.0
#
#                Yield(Kg/Hectare)
# Continent
# South America           677192.7
# Asia                   1171871.4
# North America          1082602.4
# Africa                 2142107.5
# Oceania                 162419.1
# Europe                  131870.9

# %%
dfconti.sort_values('Production(Tons)',ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
dfconti['Production(Tons)'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
dfconti['Acreage(Hectare)'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
dfconti.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.994897           0.091201
# Production_per_Person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000

# %%
sns.heatmap(dfconti.corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
dfconti
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# Africa                 2142107.5
# Asia                   1171871.4
# Europe                  131870.9
# North America          1082602.4
# Oceania                 162419.1
# South America           677192.7

# %%
df
# Out:
#        Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0       Brazil  South America       768678382.0                   3668.531
# 1        India           Asia       348448000.0                 260721.000
# 2        China           Asia       123059739.0                  88287.000
# 3     Thailand           Asia        87468496.0                   1264.303
# 4     Pakistan           Asia        65450704.0                 324219.000
# ..         ...            ...               ...                        ...
# 97       Spain         Europe             394.0                      8.000
# 98     Lebanon           Asia              97.0                     16.000
# 99   Singapore           Asia              50.0                      9.000
# 100      Samoa        Oceania              12.0                      6.000
# 101      Syria           Asia               1.0                      0.000
#
#      Acreage(Hectare)  Yield(Kg/Hectare)
# ...

# %%
dfconti["No_of_Countries"]=df.groupby('Continent').count()['Country']

# %%
dfconti
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  No_of_Countries
# Continent
# Africa                 2142107.5               38
# Asia                   1171871.4               25
# Europe                  131870.9                2
# North America          1082602.4               22
# Oceania                 162419.1                4
# South America           677192.7               11

# %%
continames=dfconti.index.to_list()
sns.lineplot(data=dfconti,x="No_of_Countries",y="Production(Tons)")
plt.xticks(dfconti["No_of_Countries"],continames,rotation=45)
plt.show()

# %%
dfconti.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# No_of_Countries                    0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_Person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# No_of_Countries                    0.132817           0.989712
#
#                            No_of_Countries
# Production(Tons)                  0.109244
# Production_per_Person(Kg)         0.540086
# ...

# %%
dfconti['Production(Tons)'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production(Tons)'>
